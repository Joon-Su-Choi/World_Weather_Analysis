# %%
# importing dependencies.
import json
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import timeit
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# generate random list of 2000 latitude and longitute.
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180, high=180, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs


###city_list = []

# loop through the latitute and longitude and find nearest city.
# add the city if it is unique.
###for x in range(2000):
###    add_city = citipy.nearest_city(lats[x], lngs[x]).city_name
    
###    if add_city not in city_list:
###        city_list.append(add_city)

# check number of cities
###len(city_list)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
 
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 731

# %%
# Create an empty list to hold the weather data.
city_data = []

# Create counters
record_count = 1
set_count = 1

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
     # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
     # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_wdescription = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_wdescription,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
                          

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 15 | tasiilaq
# Processing Record 2 of Set 15 | ushuaia
# Processing Record 3 of Set 15 | sao filipe
# Processing Record 4 of Set 15 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 15 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 15 | teya
# Processing Record 7 of Set 15 | hilo
# Processing Record 8 of Set 15 | rikitea
# Processing Record 9 of Set 15 | bilibino
# Processing Record 10 of Set 15 | mataura
# Processing Record 11 of Set 15 | ballina
# Processing Record 12 of Set 15 | karratha
# Processing Record 13 of Set 15 | georgetown
# Processing Record 14 of Set 15 | camp verde
# Processing Record 15 of Set 15 | aden
# Processing Record 16 of Set 15 | ebeltoft
# Processing Record 17 of Set 15 | divnomorskoye
# Processing Record 18 of Set 15 | bilma
# Processing Record 19 of Set 15 | albany
# Processing Record 20 of Set 15 | sobolevo
# Processing Record 21 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 22 of Set 15 | rawson
# Processing Record 23 of Set 15 | tuktoyaktuk
# Processing Record 24 of Set 15 | ziro
# Processing Record 25 of Set 15 | butaritari
# Processing Record 26 of Set 15 | saint-philippe
# Processing Record 27 of Set 15 | saskatoon
# Processing Record 28 of Set 15 | oum hadjer
# Processing Record 29 of Set 15 | the valley
# Processing Record 30 of Set 15 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 15 | luderitz
# Processing Record 32 of Set 15 | kaitangata
# Processing Record 33 of Set 15 | bambanglipuro
# Processing Record 34 of Set 15 | aripuana
# Processing Record 35 of Set 15 | hermanus
# Processing Record 36 of Set 15 | umba
# Processing Record 37 of Set 15 | arraial do cabo
# Processing Record 38 of Set 15 | vila franca do campo
# Processing Record 39 of Set 15 | barrow
# Processing Record 40 of Set 15 | bida
# Processing Record 41 of Set 15 | yerbogachen
# Processing Record 42 of Set 15 | port alfred
# Processing Record 43 of Set 15 | severo-kurilsk
# Processing Record 44 of Set 15 | punta arenas
# Processing Record 45 of Set 15 | victoria
# Processing Record 46 of Set 15 | naze
# Processing Record 47 of Set 15 | upernavik
# Processing Record 48 of Set 15 | sanchor
# Processing Record 49 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 15 | carballo
# Processing Record 1 of Set 16 | thompson
# Processing Record 2 of Set 16 | dolbeau
# City not found. Skipping...
# Processing Record 3 of Set 16 | narsaq
# Processing Record 4 of Set 16 | busselton
# Processing Record 5 of Set 16 | cabo san lucas
# Processing Record 6 of Set 16 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 16 | nome
# Processing Record 8 of Set 16 | vaini
# Processing Record 9 of Set 16 | eureka
# Processing Record 10 of Set 16 | port blair
# Processing Record 11 of Set 16 | bredasdorp
# Processing Record 12 of Set 16 | kawalu
# Processing Record 13 of Set 16 | esperance
# Processing Record 14 of Set 16 | kruisfontein
# Processing Record 15 of Set 16 | port elizabeth
# Processing Record 16 of Set 16 | pevek
# Processing Record 17 of Set 16 | mapiripan
# Processing Record 18 of Set 16 | sao felix do xingu
# Processing Record 19 of Set 16 | hohhot
# Processing Record 20 of Set 16 | itanhem
# Processing Record 21 of Set 16 | la tuque
# Processing Record 22 of Set 16 | khandbari
# Processing Record 23 of Set 16 | nikolskoye
# Processing Record 24 of Set 16 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 16 | malinovoye ozero
# Processing Record 26 of Set 16 | ahipara
# Processing Record 27 of Set 16 | husavik
# Processing Record 28 of Set 16 | kununurra
# Processing Record 29 of Set 16 | kapaa
# Processing Record 30 of Set 16 | faanui
# Processing Record 31 of Set 16 | luau
# Processing Record 32 of Set 16 | bonthe
# Processing Record 33 of Set 16 | teahupoo
# Processing Record 34 of Set 16 | bethel
# Processing Record 35 of Set 16 | carnarvon
# Processing Record 36 of Set 16 | coihaique
# Processing Record 37 of Set 16 | avarua
# Processing Record 38 of Set 16 | saint-pierre
# Processing Record 39 of Set 16 | atuona
# Processing Record 40 of Set 16 | northam
# Processing Record 41 of Set 16 | bayan
# Processing Record 42 of Set 16 | airai
# Processing Record 43 of Set 16 | bluff
# Processing Record 44 of Set 16 | khatanga
# Processing Record 45 of Set 16 | east london
# Processing Record 46 of Set 16 | hithadhoo
# Processing Record 47 of Set 16 | mandalgovi
# Processing Record 48 of Set 16 | ponta do sol
# Processing Record 49 of Set 16 | dharchula
# Processing Record 50 of Set 16 | parkes
# Processing Record 1 of Set 17 | wote
# Processing Record 2 of Set 17 | sterling
# Processing Record 3 of Set 17 | bengkulu
# Processing Record 4 of Set 17 | mayo
# Processing Record 5 of Set 17 | muli
# Processing Record 6 of Set 17 | nanortalik
# Processing Record 7 of Set 17 | kitob
# Processing Record 8 of Set 17 | labrea
# Processing Record 9 of Set 17 | kiama
# Processing Record 10 of Set 17 | vao
# Processing Record 11 of Set 17 | aklavik
# Processing Record 12 of Set 17 | cockburn town
# Processing Record 13 of Set 17 | honiara
# Processing Record 14 of Set 17 | mar del plata
# Processing Record 15 of Set 17 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 17 | new norfolk
# Processing Record 17 of Set 17 | tshikapa
# Processing Record 18 of Set 17 | mehamn
# Processing Record 19 of Set 17 | marzuq
# Processing Record 20 of Set 17 | biak
# Processing Record 21 of Set 17 | yellowknife
# Processing Record 22 of Set 17 | fortuna
# Processing Record 23 of Set 17 | bonfim
# Processing Record 24 of Set 17 | saskylakh
# Processing Record 25 of Set 17 | rincon
# Processing Record 26 of Set 17 | vila velha
# Processing Record 27 of Set 17 | darhan
# Processing Record 28 of Set 17 | qaanaaq
# Processing Record 29 of Set 17 | cape town
# Processing Record 30 of Set 17 | jamestown
# Processing Record 31 of Set 17 | sangar
# Processing Record 32 of Set 17 | maniitsoq
# Processing Record 33 of Set 17 | jiuquan
# Processing Record 34 of Set 17 | grand centre
# City not found. Skipping...
# Processing Record 35 of Set 17 | pangoa
# Processing Record 36 of Set 17 | chokurdakh
# Processing Record 37 of Set 17 | salalah
# Processing Record 38 of Set 17 | princeton
# Processing Record 39 of Set 17 | alamos
# Processing Record 40 of Set 17 | saint anthony
# Processing Record 41 of Set 17 | torbay
# Processing Record 42 of Set 17 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 17 | hobyo
# Processing Record 44 of Set 17 | santa fe
# Processing Record 45 of Set 17 | raub
# Processing Record 46 of Set 17 | el cope
# Processing Record 47 of Set 17 | tahara
# Processing Record 48 of Set 17 | lorengau
# Processing Record 49 of Set 17 | guerrero negro
# Processing Record 50 of Set 17 | rocha
# Processing Record 1 of Set 18 | kijang
# Processing Record 2 of Set 18 | henties bay
# Processing Record 3 of Set 18 | shelburne
# Processing Record 4 of Set 18 | zalantun
# Processing Record 5 of Set 18 | souillac
# Processing Record 6 of Set 18 | half moon bay
# Processing Record 7 of Set 18 | mahebourg
# Processing Record 8 of Set 18 | bichena
# Processing Record 9 of Set 18 | hurricane
# Processing Record 10 of Set 18 | castro
# Processing Record 11 of Set 18 | katangli
# Processing Record 12 of Set 18 | college
# Processing Record 13 of Set 18 | tiksi
# Processing Record 14 of Set 18 | hasaki
# Processing Record 15 of Set 18 | chake chake
# Processing Record 16 of Set 18 | hopkinton
# Processing Record 17 of Set 18 | necochea
# Processing Record 18 of Set 18 | bertoua
# Processing Record 19 of Set 18 | ancud
# Processing Record 20 of Set 18 | bubaque
# Processing Record 21 of Set 18 | barra do garcas
# Processing Record 22 of Set 18 | longyearbyen
# Processing Record 23 of Set 18 | nuuk
# Processing Record 24 of Set 18 | berasia
# Processing Record 25 of Set 18 | geraldton
# Processing Record 26 of Set 18 | pauini
# Processing Record 27 of Set 18 | san quintin
# Processing Record 28 of Set 18 | kavaratti
# Processing Record 29 of Set 18 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 18 | bytosh
# Processing Record 31 of Set 18 | robertsport
# Processing Record 32 of Set 18 | chumikan
# Processing Record 33 of Set 18 | ibra
# Processing Record 34 of Set 18 | colomi
# Processing Record 35 of Set 18 | sola
# Processing Record 36 of Set 18 | beringovskiy
# Processing Record 37 of Set 18 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 18 | iqaluit
# Processing Record 39 of Set 18 | imbituba
# Processing Record 40 of Set 18 | ploemeur
# Processing Record 41 of Set 18 | stornoway
# Processing Record 42 of Set 18 | sabancuy
# Processing Record 43 of Set 18 | hay river
# Processing Record 44 of Set 18 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 18 | hualmay
# Processing Record 46 of Set 18 | ranong
# Processing Record 47 of Set 18 | leningradskiy
# Processing Record 48 of Set 18 | ludvika
# Processing Record 49 of Set 18 | safwah
# City not found. Skipping...
# Processing Record 50 of Set 18 | bimbo
# Processing Record 1 of Set 19 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 19 | olafsvik
# Processing Record 3 of Set 19 | mogzon
# Processing Record 4 of Set 19 | benguela
# Processing Record 5 of Set 19 | skeldon
# Processing Record 6 of Set 19 | horsham
# Processing Record 7 of Set 19 | tura
# Processing Record 8 of Set 19 | falealupo
# City not found. Skipping...
# Processing Record 9 of Set 19 | kantunilkin
# Processing Record 10 of Set 19 | dwarka
# Processing Record 11 of Set 19 | saldanha
# Processing Record 12 of Set 19 | heinola
# Processing Record 13 of Set 19 | brezno
# Processing Record 14 of Set 19 | kodiak
# Processing Record 15 of Set 19 | chilac
# City not found. Skipping...
# Processing Record 16 of Set 19 | keetmanshoop
# Processing Record 17 of Set 19 | copiapo
# Processing Record 18 of Set 19 | lata
# Processing Record 19 of Set 19 | jalu
# Processing Record 20 of Set 19 | ribeira grande
# Processing Record 21 of Set 19 | hamilton
# Processing Record 22 of Set 19 | nabire
# Processing Record 23 of Set 19 | adrar
# Processing Record 24 of Set 19 | gambela
# Processing Record 25 of Set 19 | guarapari
# Processing Record 26 of Set 19 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 19 | puerto ayora
# Processing Record 28 of Set 19 | hobart
# Processing Record 29 of Set 19 | iquitos
# Processing Record 30 of Set 19 | marawi
# Processing Record 31 of Set 19 | rolim de moura
# City not found. Skipping...
# Processing Record 32 of Set 19 | gien
# Processing Record 33 of Set 19 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 19 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 19 | ambilobe
# Processing Record 36 of Set 19 | dikson
# Processing Record 37 of Set 19 | zabaykalsk
# Processing Record 38 of Set 19 | goderich
# Processing Record 39 of Set 19 | guanambi
# Processing Record 40 of Set 19 | kuche
# City not found. Skipping...
# Processing Record 41 of Set 19 | el rosario
# Processing Record 42 of Set 19 | inhambane
# Processing Record 43 of Set 19 | fort nelson
# Processing Record 44 of Set 19 | vardo
# Processing Record 45 of Set 19 | senador guiomard
# Processing Record 46 of Set 19 | namatanai
# Processing Record 47 of Set 19 | ostrovnoy
# Processing Record 48 of Set 19 | jarjis
# City not found. Skipping...
# Processing Record 49 of Set 19 | krasnyy chikoy
# Processing Record 50 of Set 19 | sataua
# City not found. Skipping...
# Processing Record 1 of Set 20 | anadyr
# Processing Record 2 of Set 20 | milas
# Processing Record 3 of Set 20 | golaesti
# Processing Record 4 of Set 20 | hofn
# Processing Record 5 of Set 20 | tiangua
# Processing Record 6 of Set 20 | kamenka
# Processing Record 7 of Set 20 | la ronge
# Processing Record 8 of Set 20 | hervey bay
# Processing Record 9 of Set 20 | nioro
# Processing Record 10 of Set 20 | berlevag
# Processing Record 11 of Set 20 | norwich
# Processing Record 12 of Set 20 | rognan
# Processing Record 13 of Set 20 | havoysund
# Processing Record 14 of Set 20 | biltine
# Processing Record 15 of Set 20 | kenai
# Processing Record 16 of Set 20 | auki
# Processing Record 17 of Set 20 | merauke
# Processing Record 18 of Set 20 | vikulovo
# Processing Record 19 of Set 20 | laguna
# Processing Record 20 of Set 20 | inza
# Processing Record 21 of Set 20 | flinders
# Processing Record 22 of Set 20 | sitka
# Processing Record 23 of Set 20 | bathsheba
# Processing Record 24 of Set 20 | maragogi
# Processing Record 25 of Set 20 | zhigansk
# Processing Record 26 of Set 20 | san andres
# Processing Record 27 of Set 20 | noumea
# Processing Record 28 of Set 20 | buldana
# Processing Record 29 of Set 20 | lompoc
# Processing Record 30 of Set 20 | kieta
# Processing Record 31 of Set 20 | zambezi
# Processing Record 32 of Set 20 | taoudenni
# Processing Record 33 of Set 20 | yar-sale
# Processing Record 34 of Set 20 | cam ranh
# Processing Record 35 of Set 20 | cidreira
# Processing Record 36 of Set 20 | burnie
# Processing Record 37 of Set 20 | staryy nadym
# Processing Record 38 of Set 20 | cacheu
# Processing Record 39 of Set 20 | san patricio
# Processing Record 40 of Set 20 | shchelyayur
# City not found. Skipping...
# Processing Record 41 of Set 20 | saint-francois
# Processing Record 42 of Set 20 | bambous virieux
# Processing Record 43 of Set 20 | conde
# Processing Record 44 of Set 20 | talnakh
# Processing Record 45 of Set 20 | pandan
# Processing Record 46 of Set 20 | tiarei
# Processing Record 47 of Set 20 | inirida
# Processing Record 48 of Set 20 | provideniya
# Processing Record 49 of Set 20 | leh
# Processing Record 50 of Set 20 | norman wells
# Processing Record 1 of Set 21 | christchurch
# Processing Record 2 of Set 21 | jibuti
# Processing Record 3 of Set 21 | guiratinga
# Processing Record 4 of Set 21 | beli manastir
# Processing Record 5 of Set 21 | tambopata
# Processing Record 6 of Set 21 | tondano
# Processing Record 7 of Set 21 | pisco
# Processing Record 8 of Set 21 | tuatapere
# Processing Record 9 of Set 21 | savelugu
# Processing Record 10 of Set 21 | niteroi
# Processing Record 11 of Set 21 | yantal
# Processing Record 12 of Set 21 | agadez
# Processing Record 13 of Set 21 | livingston
# Processing Record 14 of Set 21 | athabasca
# Processing Record 15 of Set 21 | lazaro cardenas
# Processing Record 16 of Set 21 | kloulklubed
# Processing Record 17 of Set 21 | arinos
# Processing Record 18 of Set 21 | batagay-alyta
# Processing Record 19 of Set 21 | masakin
# Processing Record 20 of Set 21 | pochutla
# Processing Record 21 of Set 21 | caluquembe
# Processing Record 22 of Set 21 | batemans bay
# Processing Record 23 of Set 21 | tazovskiy
# Processing Record 24 of Set 21 | pahrump
# Processing Record 25 of Set 21 | vanimo
# Processing Record 26 of Set 21 | sao jose da coroa grande
# Processing Record 27 of Set 21 | luwuk
# Processing Record 28 of Set 21 | silver city
# Processing Record 29 of Set 21 | palanga
# Processing Record 30 of Set 21 | taltal
# Processing Record 31 of Set 21 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 21 | vannes
# Processing Record 33 of Set 21 | port hardy
# Processing Record 34 of Set 21 | benidorm
# Processing Record 35 of Set 21 | waipawa
# Processing Record 36 of Set 21 | pemba
# Processing Record 37 of Set 21 | lagoa
# Processing Record 38 of Set 21 | clyde river
# Processing Record 39 of Set 21 | diego de almagro
# Processing Record 40 of Set 21 | borgarnes
# Processing Record 41 of Set 21 | taburi
# City not found. Skipping...
# Processing Record 42 of Set 21 | lilongwe
# Processing Record 43 of Set 21 | abashiri
# Processing Record 44 of Set 21 | harper
# Processing Record 45 of Set 21 | nisia floresta
# Processing Record 46 of Set 21 | massaguet
# Processing Record 47 of Set 21 | ambodifototra
# City not found. Skipping...
# Processing Record 48 of Set 21 | beyneu
# Processing Record 49 of Set 21 | tuggurt
# City not found. Skipping...
# Processing Record 50 of Set 21 | lavrentiya
# Processing Record 1 of Set 22 | cherskiy
# Processing Record 2 of Set 22 | tigil
# Processing Record 3 of Set 22 | yavoriv
# Processing Record 4 of Set 22 | udachnyy
# Processing Record 5 of Set 22 | fallon
# Processing Record 6 of Set 22 | fort-de-france
# Processing Record 7 of Set 22 | touros
# Processing Record 8 of Set 22 | pouembout
# Processing Record 9 of Set 22 | dingle
# Processing Record 10 of Set 22 | rafsanjan
# Processing Record 11 of Set 22 | nemuro
# Processing Record 12 of Set 22 | salinas
# Processing Record 13 of Set 22 | plettenberg bay
# Processing Record 14 of Set 22 | chicama
# Processing Record 15 of Set 22 | coquimbo
# Processing Record 16 of Set 22 | grindavik
# Processing Record 17 of Set 22 | aktas
# Processing Record 18 of Set 22 | samfya
# Processing Record 19 of Set 22 | steamboat springs
# Processing Record 20 of Set 22 | albertville
# Processing Record 21 of Set 22 | lockhart
# Processing Record 22 of Set 22 | aborlan
# Processing Record 23 of Set 22 | camacupa
# Processing Record 24 of Set 22 | arman
# Processing Record 25 of Set 22 | palana
# Processing Record 26 of Set 22 | sofiyivka
# Processing Record 27 of Set 22 | yumen
# Processing Record 28 of Set 22 | bonavista
# Processing Record 29 of Set 22 | comodoro rivadavia
# Processing Record 30 of Set 22 | aketi
# Processing Record 31 of Set 22 | acapulco
# Processing Record 32 of Set 22 | kurilsk
# Processing Record 33 of Set 22 | elat
# Processing Record 34 of Set 22 | glens falls
# Processing Record 35 of Set 22 | lalomanu
# City not found. Skipping...
# Processing Record 36 of Set 22 | markova
# Processing Record 37 of Set 22 | dryden
# Processing Record 38 of Set 22 | saint-georges
# Processing Record 39 of Set 22 | sierning
# Processing Record 40 of Set 22 | santiago
# Processing Record 41 of Set 22 | mobai
# Processing Record 42 of Set 22 | mrirt
# City not found. Skipping...
# Processing Record 43 of Set 22 | aguimes
# Processing Record 44 of Set 22 | meulaboh
# Processing Record 45 of Set 22 | zmiyiv
# Processing Record 46 of Set 22 | isangel
# Processing Record 47 of Set 22 | toftir
# City not found. Skipping...
# Processing Record 48 of Set 22 | keita
# Processing Record 49 of Set 22 | maebaru
# Processing Record 50 of Set 22 | playa del carmen
# Processing Record 1 of Set 23 | launceston
# Processing Record 2 of Set 23 | srednekolymsk
# Processing Record 3 of Set 23 | yorkton
# Processing Record 4 of Set 23 | honningsvag
# Processing Record 5 of Set 23 | wick
# Processing Record 6 of Set 23 | kifri
# Processing Record 7 of Set 23 | lazo
# Processing Record 8 of Set 23 | riyadh
# Processing Record 9 of Set 23 | dujuma
# City not found. Skipping...
# Processing Record 10 of Set 23 | predivinsk
# Processing Record 11 of Set 23 | weener
# Processing Record 12 of Set 23 | breves
# Processing Record 13 of Set 23 | shimoda
# Processing Record 14 of Set 23 | kavieng
# Processing Record 15 of Set 23 | saint-leu
# Processing Record 16 of Set 23 | ruwi
# Processing Record 17 of Set 23 | pokhara
# Processing Record 18 of Set 23 | wanning
# Processing Record 19 of Set 23 | nantucket
# Processing Record 20 of Set 23 | kegayli
# City not found. Skipping...
# Processing Record 21 of Set 23 | hami
# Processing Record 22 of Set 23 | asau
# Processing Record 23 of Set 23 | emmett
# Processing Record 24 of Set 23 | neiba
# Processing Record 25 of Set 23 | champerico
# Processing Record 26 of Set 23 | ixtapa
# Processing Record 27 of Set 23 | charters towers
# Processing Record 28 of Set 23 | paamiut
# Processing Record 29 of Set 23 | jabiru
# City not found. Skipping...
# Processing Record 30 of Set 23 | ilulissat
# Processing Record 31 of Set 23 | bull savanna
# Processing Record 32 of Set 23 | steinbach
# Processing Record 33 of Set 23 | butka
# Processing Record 34 of Set 23 | surt
# Processing Record 35 of Set 23 | lasa
# Processing Record 36 of Set 23 | norrtalje
# Processing Record 37 of Set 23 | kamaishi
# Processing Record 38 of Set 23 | manthani
# Processing Record 39 of Set 23 | kahului
# Processing Record 40 of Set 23 | omboue
# Processing Record 41 of Set 23 | nova vicosa
# Processing Record 42 of Set 23 | cabedelo
# Processing Record 43 of Set 23 | codrington
# Processing Record 44 of Set 23 | kumylzhenskaya
# Processing Record 45 of Set 23 | sorland
# Processing Record 46 of Set 23 | belousovka
# Processing Record 47 of Set 23 | brae
# Processing Record 48 of Set 23 | luanda
# Processing Record 49 of Set 23 | quebrada de arena
# Processing Record 50 of Set 23 | gamba
# Processing Record 1 of Set 24 | mitsamiouli
# Processing Record 2 of Set 24 | maarianhamina
# Processing Record 3 of Set 24 | huilong
# Processing Record 4 of Set 24 | cayenne
# Processing Record 5 of Set 24 | slidell
# Processing Record 6 of Set 24 | zholymbet
# Processing Record 7 of Set 24 | sioux lookout
# Processing Record 8 of Set 24 | sadalgi
# Processing Record 9 of Set 24 | rexburg
# Processing Record 10 of Set 24 | port-gentil
# Processing Record 11 of Set 24 | ozernovskiy
# Processing Record 12 of Set 24 | ambon
# Processing Record 13 of Set 24 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 24 | astoria
# Processing Record 15 of Set 24 | west wendover
# Processing Record 16 of Set 24 | innisfail
# Processing Record 17 of Set 24 | itoman
# Processing Record 18 of Set 24 | paramonga
# Processing Record 19 of Set 24 | luban
# Processing Record 20 of Set 24 | maku
# Processing Record 21 of Set 24 | kamnik
# Processing Record 22 of Set 24 | rawannawi
# City not found. Skipping...
# Processing Record 23 of Set 24 | mazatan
# Processing Record 24 of Set 24 | bismarck
# Processing Record 25 of Set 24 | alofi
# Processing Record 26 of Set 24 | mendahara
# City not found. Skipping...
# Processing Record 27 of Set 24 | mahwa
# Processing Record 28 of Set 24 | ossora
# Processing Record 29 of Set 24 | yulara
# Processing Record 30 of Set 24 | nawa
# Processing Record 31 of Set 24 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 24 | bandar
# Processing Record 33 of Set 24 | dali
# Processing Record 34 of Set 24 | barcelona
# Processing Record 35 of Set 24 | ocos
# Processing Record 36 of Set 24 | slavsk
# Processing Record 37 of Set 24 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 24 | andenes
# Processing Record 39 of Set 24 | rodrigues alves
# Processing Record 40 of Set 24 | labuan
# Processing Record 41 of Set 24 | bara
# Processing Record 42 of Set 24 | puntarenas
# Processing Record 43 of Set 24 | lebu
# Processing Record 44 of Set 24 | singaraja
# Processing Record 45 of Set 24 | mindelo
# Processing Record 46 of Set 24 | nuqui
# Processing Record 47 of Set 24 | jovellar
# Processing Record 48 of Set 24 | santa isabel do rio negro
# Processing Record 49 of Set 24 | hvolsvollur
# Processing Record 50 of Set 24 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 1 of Set 25 | kirakira
# Processing Record 2 of Set 25 | vallenar
# Processing Record 3 of Set 25 | bani
# Processing Record 4 of Set 25 | richards bay
# Processing Record 5 of Set 25 | dabola
# Processing Record 6 of Set 25 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 25 | candido mendes
# Processing Record 8 of Set 25 | korla
# Processing Record 9 of Set 25 | goure
# Processing Record 10 of Set 25 | gorontalo
# Processing Record 11 of Set 25 | cyangugu
# Processing Record 12 of Set 25 | boa vista
# Processing Record 13 of Set 25 | vestmannaeyjar
# Processing Record 14 of Set 25 | kyren
# Processing Record 15 of Set 25 | praia da vitoria
# Processing Record 16 of Set 25 | kathu
# Processing Record 17 of Set 25 | marsh harbour
# Processing Record 18 of Set 25 | moose factory
# Processing Record 19 of Set 25 | barra dos coqueiros
# Processing Record 20 of Set 25 | simiti
# Processing Record 21 of Set 25 | la gomera
# Processing Record 22 of Set 25 | port lincoln
# Processing Record 23 of Set 25 | montague
# Processing Record 24 of Set 25 | san cristobal
# Processing Record 25 of Set 25 | borogontsy
# Processing Record 26 of Set 25 | solnechnyy
# Processing Record 27 of Set 25 | plouzane
# Processing Record 28 of Set 25 | pacifica
# Processing Record 29 of Set 25 | mulege
# Processing Record 30 of Set 25 | parthenay
# Processing Record 31 of Set 25 | mazsalaca
# Processing Record 32 of Set 25 | marquette
# Processing Record 33 of Set 25 | talas
# Processing Record 34 of Set 25 | tukums
# Processing Record 35 of Set 25 | quatre cocos
# Processing Record 36 of Set 25 | hayden
# Processing Record 37 of Set 25 | cap malheureux
# Processing Record 38 of Set 25 | nieuw amsterdam
# Processing Record 39 of Set 25 | labytnangi
# Processing Record 40 of Set 25 | pozzallo
# Processing Record 41 of Set 25 | terenos
# Processing Record 42 of Set 25 | jumla
# Processing Record 43 of Set 25 | samarai
# Processing Record 44 of Set 25 | los llanos de aridane
# Processing Record 45 of Set 25 | pueblo
# Processing Record 46 of Set 25 | nikko
# Processing Record 47 of Set 25 | beboto
# Processing Record 48 of Set 25 | oskemen
# Processing Record 49 of Set 25 | marsa matruh
# Processing Record 50 of Set 25 | portree
# Processing Record 1 of Set 26 | butterworth
# Processing Record 2 of Set 26 | lamu
# Processing Record 3 of Set 26 | vuktyl
# Processing Record 4 of Set 26 | nyurba
# Processing Record 5 of Set 26 | san isidro
# Processing Record 6 of Set 26 | awjilah
# Processing Record 7 of Set 26 | isiro
# Processing Record 8 of Set 26 | severodvinsk
# Processing Record 9 of Set 26 | gummidipundi
# Processing Record 10 of Set 26 | mastic beach
# Processing Record 11 of Set 26 | micheweni
# Processing Record 12 of Set 26 | tena
# Processing Record 13 of Set 26 | amarillo
# Processing Record 14 of Set 26 | anqing
# Processing Record 15 of Set 26 | ryotsu
# Processing Record 16 of Set 26 | badin
# Processing Record 17 of Set 26 | san carlos de bariloche
# Processing Record 18 of Set 26 | puro
# Processing Record 19 of Set 26 | lodja
# Processing Record 20 of Set 26 | constitucion
# Processing Record 21 of Set 26 | gushikawa
# Processing Record 22 of Set 26 | naila
# Processing Record 23 of Set 26 | midland
# Processing Record 24 of Set 26 | haines junction
# Processing Record 25 of Set 26 | grand gaube
# Processing Record 26 of Set 26 | aldan
# Processing Record 27 of Set 26 | katsuura
# Processing Record 28 of Set 26 | truth or consequences
# Processing Record 29 of Set 26 | akyab
# Processing Record 30 of Set 26 | kuytun
# Processing Record 31 of Set 26 | lira
# Processing Record 32 of Set 26 | paengaroa
# Processing Record 33 of Set 26 | togitsu
# Processing Record 34 of Set 26 | dir
# Processing Record 35 of Set 26 | maun
# Processing Record 36 of Set 26 | pitimbu
# Processing Record 37 of Set 26 | datong
# Processing Record 38 of Set 26 | nacala
# Processing Record 39 of Set 26 | geri
# Processing Record 40 of Set 26 | bodden town
# Processing Record 41 of Set 26 | mogadishu
# Processing Record 42 of Set 26 | skarnes
# Processing Record 43 of Set 26 | ruatoria
# City not found. Skipping...
# Processing Record 44 of Set 26 | huaicheng
# Processing Record 45 of Set 26 | hovd
# Processing Record 46 of Set 26 | notse
# Processing Record 47 of Set 26 | ilam
# Processing Record 48 of Set 26 | singapore
# Processing Record 49 of Set 26 | bullas
# Processing Record 50 of Set 26 | chuy
# Processing Record 1 of Set 27 | khvastovichi
# Processing Record 2 of Set 27 | fare
# Processing Record 3 of Set 27 | trinidad
# Processing Record 4 of Set 27 | bandarbeyla
# Processing Record 5 of Set 27 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 27 | andradina
# Processing Record 7 of Set 27 | sinnamary
# Processing Record 8 of Set 27 | niquero
# Processing Record 9 of Set 27 | sembakung
# Processing Record 10 of Set 27 | sumbawa
# City not found. Skipping...
# Processing Record 11 of Set 27 | muscat
# Processing Record 12 of Set 27 | virginia beach
# Processing Record 13 of Set 27 | isabela
# Processing Record 14 of Set 27 | balabac
# Processing Record 15 of Set 27 | loiza
# Processing Record 16 of Set 27 | torata
# Processing Record 17 of Set 27 | hudson bay
# Processing Record 18 of Set 27 | forrest city
# Processing Record 19 of Set 27 | flin flon
# Processing Record 20 of Set 27 | gizo
# Processing Record 21 of Set 27 | qandala
# Processing Record 22 of Set 27 | caravelas
# Processing Record 23 of Set 27 | mount isa
# Processing Record 24 of Set 27 | klaksvik
# Processing Record 25 of Set 27 | talaya
# Processing Record 26 of Set 27 | hokitika
# Processing Record 27 of Set 27 | veraval
# Processing Record 28 of Set 27 | sistranda
# Processing Record 29 of Set 27 | truro
# Processing Record 30 of Set 27 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 27 | wulanhaote
# City not found. Skipping...
# Processing Record 32 of Set 27 | comendador
# Processing Record 33 of Set 27 | kodinsk
# Processing Record 34 of Set 27 | bossangoa
# Processing Record 35 of Set 27 | nchelenge
# Processing Record 36 of Set 27 | ajjampur
# Processing Record 37 of Set 27 | manaquiri
# Processing Record 38 of Set 27 | gorgan
# Processing Record 39 of Set 27 | chatham
# Processing Record 40 of Set 27 | katima mulilo
# Processing Record 41 of Set 27 | igaci
# Processing Record 42 of Set 27 | palmer
# Processing Record 43 of Set 27 | shenjiamen
# Processing Record 44 of Set 27 | tashara
# Processing Record 45 of Set 27 | mandal
# Processing Record 46 of Set 27 | mount gambier
# Processing Record 47 of Set 27 | bridlington
# Processing Record 48 of Set 27 | sungaipenuh
# Processing Record 49 of Set 27 | belem
# Processing Record 50 of Set 27 | urfa
# City not found. Skipping...
# Processing Record 1 of Set 28 | bargal
# City not found. Skipping...
# Processing Record 2 of Set 28 | muros
# Processing Record 3 of Set 28 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 28 | kudahuvadhoo
# Processing Record 5 of Set 28 | leeton
# Processing Record 6 of Set 28 | himora
# City not found. Skipping...
# Processing Record 7 of Set 28 | shingu
# Processing Record 8 of Set 28 | porto novo
# Processing Record 9 of Set 28 | benghazi
# Processing Record 10 of Set 28 | pangkalanbuun
# Processing Record 11 of Set 28 | kirkenaer
# Processing Record 12 of Set 28 | craig
# Processing Record 13 of Set 28 | pemangkat
# Processing Record 14 of Set 28 | hemnesberget
# Processing Record 15 of Set 28 | santiago de maria
# Processing Record 16 of Set 28 | burica
# City not found. Skipping...
# Processing Record 17 of Set 28 | nanakuli
# Processing Record 18 of Set 28 | umm kaddadah
# Processing Record 19 of Set 28 | lindsay
# Processing Record 20 of Set 28 | chernyshevskiy
# Processing Record 21 of Set 28 | fianga
# City not found. Skipping...
# Processing Record 22 of Set 28 | charagua
# Processing Record 23 of Set 28 | dubbo
# Processing Record 24 of Set 28 | mbandaka
# Processing Record 25 of Set 28 | madang
# Processing Record 26 of Set 28 | dovbysh
# Processing Record 27 of Set 28 | chivay
# Processing Record 28 of Set 28 | guiyang
# Processing Record 29 of Set 28 | ayan
# Processing Record 30 of Set 28 | prince rupert
# Processing Record 31 of Set 28 | pangnirtung
# Processing Record 32 of Set 28 | port keats
# Processing Record 33 of Set 28 | axtla
# City not found. Skipping...
# Processing Record 34 of Set 28 | shakawe
# Processing Record 35 of Set 28 | sooke
# Processing Record 36 of Set 28 | mogoytuy
# Processing Record 37 of Set 28 | ahvaz
# Processing Record 38 of Set 28 | rio gallegos
# Processing Record 39 of Set 28 | rochester
# Processing Record 40 of Set 28 | sept-iles
# Processing Record 41 of Set 28 | nishihara
# Processing Record 42 of Set 28 | cranbrook
# Processing Record 43 of Set 28 | bafoulabe
# Processing Record 44 of Set 28 | semirom
# Processing Record 45 of Set 28 | tommot
# Processing Record 46 of Set 28 | tarudant
# City not found. Skipping...
# Processing Record 47 of Set 28 | atar
# Processing Record 48 of Set 28 | cintalapa
# Processing Record 49 of Set 28 | hodod
# Processing Record 50 of Set 28 | boende
# Processing Record 1 of Set 29 | amga
# Processing Record 2 of Set 29 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 29 | greenfield
# Processing Record 4 of Set 29 | ghanzi
# Processing Record 5 of Set 29 | ouesso
# Processing Record 6 of Set 29 | alugan
# Processing Record 7 of Set 29 | yang talat
# Processing Record 8 of Set 29 | sindand
# City not found. Skipping...
# Processing Record 9 of Set 29 | zhumadian
# Processing Record 10 of Set 29 | miri
# Processing Record 11 of Set 29 | saint george
# Processing Record 12 of Set 29 | takaka
# Processing Record 13 of Set 29 | komsomolskiy
# Processing Record 14 of Set 29 | naryan-mar
# Processing Record 15 of Set 29 | somerset east
# Processing Record 16 of Set 29 | pleasanton
# Processing Record 17 of Set 29 | te anau
# Processing Record 18 of Set 29 | weligama
# Processing Record 19 of Set 29 | palmital
# Processing Record 20 of Set 29 | sahrak
# City not found. Skipping...
# Processing Record 21 of Set 29 | leeuwarden
# Processing Record 22 of Set 29 | chino valley
# Processing Record 23 of Set 29 | san mateo ixtatan
# Processing Record 24 of Set 29 | la sarre
# Processing Record 25 of Set 29 | qaqortoq
# Processing Record 26 of Set 29 | mahajanga
# Processing Record 27 of Set 29 | witrivier
# City not found. Skipping...
# Processing Record 28 of Set 29 | lexington
# Processing Record 29 of Set 29 | ulaangom
# Processing Record 30 of Set 29 | nelson bay
# Processing Record 31 of Set 29 | pavino
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0    Tasiilaq  65.6145  -37.6368     overcast clouds     24.96        66
# 1     Ushuaia -54.8000  -68.3000       broken clouds     42.10        85
# 2  Sao Filipe  14.8961  -24.4956           clear sky     72.57        72
# 3        Teya  60.3778   92.6267          light snow     20.35        90
# 4        Hilo  19.7297 -155.0900    scattered clouds     73.80        97
# 5     Rikitea -23.1203 -134.9692           clear sky     78.98        69
# 6    Bilibino  68.0546  166.4372           clear sky     -7.69        86
# 7     Mataura -46.1927  168.8643           clear sky     59.49        43
# 8     Ballina -28.8667  153.5667       broken clouds     77.18        80
# 9    Karratha -20.7377  116.8463       broken clouds     93.94        52
#
#    Cloudiness  Wind Speed Country
# 0         100       38.50      GL
# 1          56        6.20      AR
# 2           0       12.28      CV
# 3         100        9.08      RU
# 4          32        1.01      US
# 5           5        7.52      PF
# 6           1        5.30      RU
# 7          10        6.64      NZ
# 8          75       14.97      AU
# 9          68       17.90      AU

# %%
new_city_data_df = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df.reindex(columns=new_city_data_df)

# %%
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Tasiilaq      GL  65.6145  -37.6368     24.96        66         100
# 1     Ushuaia      AR -54.8000  -68.3000     42.10        85          56
# 2  Sao Filipe      CV  14.8961  -24.4956     72.57        72           0
# 3        Teya      RU  60.3778   92.6267     20.35        90         100
# 4        Hilo      US  19.7297 -155.0900     73.80        97          32
# 5     Rikitea      PF -23.1203 -134.9692     78.98        69           5
# 6    Bilibino      RU  68.0546  166.4372     -7.69        86           1
# 7     Mataura      NZ -46.1927  168.8643     59.49        43          10
# 8     Ballina      AU -28.8667  153.5667     77.18        80          75
# 9    Karratha      AU -20.7377  116.8463     93.94        52          68
#
#    Wind Speed Current Description
# 0       38.50     overcast clouds
# 1        6.20       broken clouds
# 2       12.28           clear sky
# 3        9.08          light snow
# 4        1.01    scattered clouds
# 5        7.52           clear sky
# 6        5.30           clear sky
# 7        6.64           clear sky
# 8       14.97       broken clouds
# 9       17.90       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
